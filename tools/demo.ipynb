# %%
from backend.tla.data.stabi.reader import parse_stabi_metadata, get_records #@TODO: fix import

# %%
url = "https://oai.sbb.berlin/"
set = 'tibetica'
#sickle = Sickle(url)
#records = sickle.ListRecords(metadataPrefix='mets', set=set, ignore_deleted=True)
records = get_records(url, set)
record = next(records)

# %%
record_parsed = parse_stabi_metadata(record)

# %%
record_parsed['metadata']
# Out:
# [{'mets': [{'schemaLocation': 'info:lc/xmlns/premis-v2 http://www.loc.gov/standards/premis/v2/premis-v2-0.xsd http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-6.xsd http://www.loc.gov/METS/ http://www.loc.gov/standards/mets/version17/mets.v1-7.xsd http://www.loc.gov/mix/v10 http://www.loc.gov/standards/mix/mix10/mix10.xsd',
#     'metsHdr': [{'CREATEDATE': '2022-07-07T06:54:12',
#       'agent': [{'OTHERTYPE': 'SOFTWARE',
#         'ROLE': 'CREATOR',
#         'TYPE': 'OTHER',
#         'name': [{'text': 'Kitodo - kitodo-ugh-2.1.3-kitodo-ugh-2.1.1-11-g4b06eaa - 30−July−2019'}],
#         'note': [{'text': 'Kitodo'}]}]}],
#     'dmdSec': [{'ID': 'DMDLOG_0000',
#       'mdWrap': [{'MDTYPE': 'MODS',
#         'xmlData': [{'mods': [{'location': [{'physicalLocation': [{'valueURI': 'http://ld.zdb-services.de/resource/organisations/DE-1',
#                 'text': 'Staatsbibliothek zu Berlin - Preußischer Kulturbesitz, Berlin, Germany'}],
# ...
